# %% [markdown]
# ## Dependencies

# %%
# !git clone https://github.com/jesus2801/splash_optimized.git
# Out:
# Cloning into 'splash_optimized'...
# remote: Enumerating objects: 184, done.
# remote: Counting objects: 100% (184/184), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 184 (delta 49), reused 184 (delta 49), pack-reused 0 (from 0)
# Receiving objects: 100% (184/184), 14.98 MiB | 33.05 MiB/s, done.
# Resolving deltas: 100% (49/49), done.

# %%
# %cd splash_optimized
# Out:
# /content/splash_optimized

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 25.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 65.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.5/237.5 kB 22.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="tYIHt5crWEY5rogvb8sY")
project = rf.workspace("angelicas-workspace-vm44h").project("swimming-and-drowning-detection-p7ain")
version = project.version(1)
dataset = version.download("yolov12")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# '/content/splash_optimized/Swimming-and-Drowning-Detection-1'

# %%
# !mv /content/splash_optimized/Swimming-and-Drowning-Detection-1 /content/splash_optimized/dataset

# %% [markdown]
# ## Execution
